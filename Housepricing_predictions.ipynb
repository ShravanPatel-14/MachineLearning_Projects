# %%
import pandas as pd
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"F:\Downloads\House_Price_train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include="object")
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df_num=df.select_dtypes(include="number")
df_cat=df.select_dtypes(include="object")

# %%
df_cat.describe(include="all")
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df_num.isnull().sum().sort_values(ascending=False)
# Out:
# LotFrontage      259
# GarageYrBlt       81
# MasVnrArea         8
# Id                 0
# OpenPorchSF        0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# EnclosedPorch      0
# HalfBath           0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# BedroomAbvGr       0
# FullBath           0
# MSSubClass         0
# BsmtFinSF2         0
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# BsmtFinSF1         0
# BsmtUnfSF          0
# BsmtHalfBath       0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# SalePrice          0
# dtype: int64

# %%
df_cat.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# MasVnrType        872
# FireplaceQu       690
# GarageType         81
# GarageCond         81
# GarageQual         81
# GarageFinish       81
# BsmtFinType2       38
# BsmtExposure       38
# BsmtFinType1       37
# BsmtQual           37
# BsmtCond           37
# Electrical          1
# KitchenQual         0
# CentralAir          0
# Functional          0
# HeatingQC           0
# Heating             0
# PavedDrive          0
# SaleType            0
# MSZoning            0
# Street              0
# Condition2          0
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# BldgType            0
# Foundation          0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# ExterQual           0
# ...

# %%
print(df_num['LotFrontage'].mean())
print(df_num['LotFrontage'].median())
# Out:
# 70.04995836802665
# 69.0

# %%
import matplotlib.pyplot as plt
for i in df_num:
    plt.figure()
    sns.kdeplot(x=i,data=df)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
for col in ["PoolQC"]:
    df_cat[col].fillna('No Value',inplace=True)

# %%
for col in ["GarageCond",]:
    df_cat[col].fillna(df_cat[col].value_counts().idxmax(),inplace=True)

# %%
df_cat.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# MiscFeature      96.301370
# Alley            93.767123
# Fence            80.753425
# MasVnrType       59.726027
# FireplaceQu      47.260274
# GarageType        5.547945
# GarageQual        5.547945
# GarageFinish      5.547945
# BsmtExposure      2.602740
# BsmtFinType2      2.602740
# BsmtFinType1      2.534247
# BsmtQual          2.534247
# BsmtCond          2.534247
# Electrical        0.068493
# GarageCond        0.000000
# Functional        0.000000
# KitchenQual       0.000000
# CentralAir        0.000000
# PavedDrive        0.000000
# HeatingQC         0.000000
# Heating           0.000000
# PoolQC            0.000000
# SaleType          0.000000
# MSZoning          0.000000
# Street            0.000000
# Condition2        0.000000
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# BldgType          0.000000
# ...

# %%
sns.histplot(x="Alley",data=df,kde=True)
# Out:
# <Axes: xlabel='Alley', ylabel='Count'>

# %%
df_cat.isnull().sum()/len(df)*100
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinType2      2.602740
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# ...

# %%
for col in ["MiscFeature"]:
    df_cat[col].fillna(df_cat[col].value_counts().idxmax(),inplace=True)

# %%
for col in ["Alley"]:
    df_cat[col].fillna(df_cat[col].value_counts().idxmax(),inplace=True)

# %%
df_cat.isnull().sum()/len(df)*100
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley             0.000000
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinType2      2.602740
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# ...

# %%
for i in["MasVnrType","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","Electrical","BsmtFinType2","FireplaceQu","GarageType","GarageFinish","GarageQual","Fence"]:
    df_cat[i].fillna(df_cat[i].value_counts().idxmax(),inplace=True)

# %%
df_cat.isnull().sum()
# Out:
# MSZoning         0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# KitchenQual      0
# Functional       0
# FireplaceQu      0
# GarageType       0
# GarageFinish     0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
df_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
for c in ["GarageYrBlt","LotFrontage"]:
    df_num[c].fillna(df_num[c].median(),inplace=True)

# %%
df_num.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       8
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df1=pd.concat([df_num,df_cat],axis=1)
df1
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageType  \
# ...

# %%
df1.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
#                 ..
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# Length: 81, dtype: int64

# %% [markdown]
# Corelationship Btween Numeriacl columns and categorical columns

# %%
df_num_corr=df_num.corr()
df_num_corr
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.009921 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.356718 -0.139781     0.032628
# LotFrontage   -0.009921   -0.356718     1.000000  0.304522     0.234812
# LotArea       -0.033226   -0.139781     0.304522  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.234812  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.053281 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.116685  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.083348  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.179459  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.214367  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.042463  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.124098 -0.002618     0.308159
# ...

# %%
df_num_corr["SalePrice"]
# Out:
# Id              -0.021917
# MSSubClass      -0.084284
# LotFrontage      0.334771
# LotArea          0.263843
# OverallQual      0.790982
# OverallCond     -0.077856
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.477493
# BsmtFinSF1       0.386420
# BsmtFinSF2      -0.011378
# BsmtUnfSF        0.214479
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# 2ndFlrSF         0.319334
# LowQualFinSF    -0.025606
# GrLivArea        0.708624
# BsmtFullBath     0.227122
# BsmtHalfBath    -0.016844
# FullBath         0.560664
# HalfBath         0.284108
# BedroomAbvGr     0.168213
# KitchenAbvGr    -0.135907
# TotRmsAbvGrd     0.533723
# Fireplaces       0.466929
# GarageYrBlt      0.466754
# GarageCars       0.640409
# GarageArea       0.623431
# WoodDeckSF       0.324413
# OpenPorchSF      0.315856
# EnclosedPorch   -0.128578
# 3SsnPorch        0.044584
# ScreenPorch      0.111447
# PoolArea         0.092404
# MiscVal         -0.021190
# ...

# %%
df_num_cols = []
df_num_cols.extend(df_num_corr[(df_num_corr["SalePrice"]>0.3)].index.values)
df_num_cols.extend(df_num_corr[(df_num_corr["SalePrice"]<-0.3) ].index.values)

# %%
df_num_cols
# Out:
# ['LotFrontage',
#  'OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'SalePrice']

# %%
sns.histplot(x="SalePrice",data=df,kde=True)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# # Corelationship between categorical Columns and continuous target variable using one way anova

# %%
from scipy.stats import f_oneway

# %%
df_cat['sp']=df_num['SalePrice']

# %%
groups = [df_cat['sp'][df_cat['BsmtExposure'] == category] for category in df_cat['BsmtExposure'].unique()]

# Perform ANOVA
f_stat, p_value = f_oneway(*groups)
print(f"F-statistic: {f_stat}, P-value: {p_value}")
# Out:
# F-statistic: 76.57793447709939, P-value: 5.39423843153302e-46

# %%
c_list=[]
nc_list=[]
for c1 in list(df_cat.columns):
    if c1 == 'sp':
        continue
    else:
        groups = [df_cat['sp'][df_cat[c1] == category] for category in df_cat[c1].unique()]
        f_stat, p_value = f_oneway(*groups)
        print(f"column : {c1}, F-statistic: {f_stat}, P-value: {p_value}")
        if p_value < 0.05:
            c_list.append(c1)
        else:
            nc_list.append(c1)
# Out:
# column : MSZoning, F-statistic: 43.84028167245718, P-value: 8.817633866272648e-35
# column : Street, F-statistic: 2.4592895583691994, P-value: 0.11704860406782483
# column : Alley, F-statistic: 1.115961128470561, P-value: 0.290964797330703
# column : LotShape, F-statistic: 40.13285166226295, P-value: 6.447523852011766e-25
# column : LandContour, F-statistic: 12.850188333283924, P-value: 2.7422167521379096e-08
# column : Utilities, F-statistic: 0.29880407484898486, P-value: 0.5847167739689381
# column : LotConfig, F-statistic: 7.809954123467792, P-value: 3.163167473604189e-06
# column : LandSlope, F-statistic: 1.9588170374149438, P-value: 0.1413963584114019
# column : Neighborhood, F-statistic: 71.78486512058272, P-value: 1.558600282771154e-225
# column : Condition1, F-statistic: 6.118017137125925, P-value: 8.904549416138853e-08
# column : Condition2, F-statistic: 2.0738986215227877, P-value: 0.043425658360948464
# ...

# %%
nc_list
# Out:
# ['Street', 'Alley', 'Utilities', 'LandSlope', 'MiscFeature']

# %%
df_cat1=df_cat[c_list]

# %%
df_cat1.columns
# Out:
# Index(['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
df_cat1.head()
# Out:
#   MSZoning LotShape LandContour LotConfig Neighborhood Condition1 Condition2  \
# 0       RL      Reg         Lvl    Inside      CollgCr       Norm       Norm
# 1       RL      Reg         Lvl       FR2      Veenker      Feedr       Norm
# 2       RL      IR1         Lvl    Inside      CollgCr       Norm       Norm
# 3       RL      IR1         Lvl    Corner      Crawfor       Norm       Norm
# 4       RL      IR1         Lvl       FR2      NoRidge       Norm       Norm
#
#   BldgType HouseStyle RoofStyle  ... FireplaceQu GarageType GarageFinish  \
# 0     1Fam     2Story     Gable  ...          Gd     Attchd          RFn
# 1     1Fam     1Story     Gable  ...          TA     Attchd          RFn
# 2     1Fam     2Story     Gable  ...          TA     Attchd          RFn
# 3     1Fam     2Story     Gable  ...          Gd     Detchd          Unf
# 4     1Fam     2Story     Gable  ...          TA     Attchd          RFn
#
# ...

# %%
cat_col=[var for var in df1.columns if df[var].dtype=="O"]
cat_col
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df_cat1=df_cat1.apply(le.fit_transform)

# %%
df1.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageType  GarageFinish  \
# 0          2003       196.0         706  ...      Attchd           RFn
# 1          1976         0.0         978  ...      Attchd           RFn
# 2          2002       162.0         486  ...      Attchd           RFn
# 3          1970         0.0         216  ...      Detchd           Unf
# 4          2000       350.0         655  ...      Attchd           RFn
#
# ...

# %% [markdown]
# # SKEWNESS

# %%
for i in df.select_dtypes(include="number"):
    print(f"skewness of {i}:{df[i].skew()}")
# Out:
# skewness of Id:0.0
# skewness of MSSubClass:1.4076567471495591
# skewness of LotFrontage:2.163569142324884
# skewness of LotArea:12.207687851233496
# skewness of OverallQual:0.2169439277628693
# skewness of OverallCond:0.6930674724842182
# skewness of YearBuilt:-0.613461172488183
# skewness of YearRemodAdd:-0.5035620027004709
# skewness of MasVnrArea:2.669084210182863
# skewness of BsmtFinSF1:1.685503071910789
# skewness of BsmtFinSF2:4.255261108933303
# skewness of BsmtUnfSF:0.9202684528039037
# skewness of TotalBsmtSF:1.5242545490627664
# skewness of 1stFlrSF:1.3767566220336365
# skewness of 2ndFlrSF:0.8130298163023265
# skewness of LowQualFinSF:9.011341288465387
# skewness of GrLivArea:1.3665603560164552
# skewness of BsmtFullBath:0.596066609663168
# skewness of BsmtHalfBath:4.103402697955168
# skewness of FullBath:0.036561558402727165
# skewness of HalfBath:0.675897448233722
# skewness of BedroomAbvGr:0.21179009627507137
# skewness of KitchenAbvGr:4.488396777072859
# ...

# %% [markdown]
# ## IQR TREATMENT

# %%
def remove_outliers(df,columns):
    for col in columns:
        q1=df[col].quantile(0.25) #first quartile 25th percentile
        q3=df[col].quantile(0.75) #third quartile 75th percentile
        iqr=q3-q1
        lower_bound=q1-1.5*iqr
        upper_bound=q3*1.5*iqr
        df=df[(df[col]>=lower_bound)&(df[col]<=upper_bound)]
    return df

# %%
columns_to_check = ['LotFrontage',
 'OverallQual',
 'YearBuilt',
 'YearRemodAdd',
 'MasVnrArea',
 'BsmtFinSF1',
 'TotalBsmtSF',
 '1stFlrSF',
 '2ndFlrSF',
 'GrLivArea',
 'FullBath',
 'TotRmsAbvGrd',
 'Fireplaces',
 'GarageYrBlt',
 'GarageCars',
 'GarageArea',
 'WoodDeckSF',
 'OpenPorchSF',
 'SalePrice'] 

df_no_outliers = remove_outliers(df_num, columns_to_check)

print("Original DataFrame:")
print(df_num.shape)
print("\nDataFrame after Outlier Treatment:")
print(df_no_outliers.shape)
# Out:
# Original DataFrame:
# (1460, 38)
#
# DataFrame after Outlier Treatment:
# (1238, 38)

# %%
for j in df.select_dtypes(include="number"):
    print(f"skewness of {j}:{df[j].skew()}")
# Out:
# skewness of Id:0.0
# skewness of MSSubClass:1.4076567471495591
# skewness of LotFrontage:2.163569142324884
# skewness of LotArea:12.207687851233496
# skewness of OverallQual:0.2169439277628693
# skewness of OverallCond:0.6930674724842182
# skewness of YearBuilt:-0.613461172488183
# skewness of YearRemodAdd:-0.5035620027004709
# skewness of MasVnrArea:2.669084210182863
# skewness of BsmtFinSF1:1.685503071910789
# skewness of BsmtFinSF2:4.255261108933303
# skewness of BsmtUnfSF:0.9202684528039037
# skewness of TotalBsmtSF:1.5242545490627664
# skewness of 1stFlrSF:1.3767566220336365
# skewness of 2ndFlrSF:0.8130298163023265
# skewness of LowQualFinSF:9.011341288465387
# skewness of GrLivArea:1.3665603560164552
# skewness of BsmtFullBath:0.596066609663168
# skewness of BsmtHalfBath:4.103402697955168
# skewness of FullBath:0.036561558402727165
# skewness of HalfBath:0.675897448233722
# skewness of BedroomAbvGr:0.21179009627507137
# skewness of KitchenAbvGr:4.488396777072859
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df_cat1.shape
# Out:
# (1460, 38)

# %%
df_no_outliers.shape
# Out:
# (1238, 38)

# %%
df_f_cat=df_cat1.loc[df_no_outliers.index,:]

# %% [markdown]
# # df2=pd.concat([df_no_outliers,df_f_cat],axis=1)

# %%
# df2

# %%
# df2.shape

# %%
# df2.isnull().sum()

# %% [markdown]
# ##  MinMaxScaler scales features to a fixed range, typically [0,1](but can be customized).

# %%
columns_to_scale = [
    'LotFrontage', 'OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
    'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea',
    'FullBath', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars',
    'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'SalePrice'
]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# minmax_scaler = MinMaxScaler()
# df_minmax_scaled = df_no_outliers.copy()
# df_minmax_scaled[columns_to_scale] = minmax_scaler.fit_transform(df_no_outliers[columns_to_scale])

# %%
# df_minmax_scaled.head()

# %%
# df2.select_dtypes(include="number")

# %% [markdown]
# # It transforms the data so that it has a mean of 0 and a standard deviation of 1.

# %%
standard_scaler = StandardScaler()
df_standard_scaled = df_no_outliers.copy()
df_standard_scaled[columns_to_scale] = standard_scaler.fit_transform(df_no_outliers[columns_to_scale])

# %%
df_standard_scaled.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60    -0.299283     8450     0.665470            5   1.006292
# 1   2          20     0.469097     9600    -0.082127            8   0.120939
# 2   3          60    -0.145607    11250     0.665470            5   0.940710
# 3   4          70    -0.555410     9550     0.665470            5  -1.879302
# 4   5          60     0.673998    14260     1.413067            5   0.907920
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0      0.838425    0.555497    0.660187  ...   -0.765381     0.219147
# 1     -0.468842   -0.565308    1.306285  ...    1.609610    -0.723524
# 2      0.790008    0.361072    0.137608  ...   -0.765381    -0.074472
# 3     -0.759346   -0.565308   -0.503739  ...   -0.765381    -0.182647
# 4      0.693173    1.436130    0.539044  ...    0.764814     0.574580
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
df_standard_scaled.describe()
# Out:
#                 Id   MSSubClass   LotFrontage       LotArea   OverallQual  \
# count  1238.000000  1238.000000  1.238000e+03   1238.000000  1.238000e+03
# mean    732.997577    53.174475 -7.784116e-17   9931.942649  6.313385e-17
# std     421.403104    38.246999  1.000404e+00   4484.898177  1.000404e+00
# min       1.000000    20.000000 -1.989720e+00   1974.000000 -3.072515e+00
# 25%     370.250000    20.000000 -5.554102e-01   7744.000000 -8.297241e-01
# 50%     738.500000    50.000000 -9.438208e-02   9410.500000 -8.212698e-02
# 75%    1096.750000    60.000000  4.178714e-01  11361.750000  6.654701e-01
# max    1460.000000   190.000000  1.240460e+01  53504.000000  2.908261e+00
#
#        OverallCond     YearBuilt  YearRemodAdd    MasVnrArea    BsmtFinSF1  \
# count  1238.000000  1.238000e+03  1.238000e+03  1.238000e+03  1.238000e+03
# mean      5.585622 -2.110679e-15  3.790900e-15  4.591552e-17  1.865318e-17
# std       1.083582  1.000404e+00  1.000404e+00  1.000404e+00  1.000404e+00
# ...

# %%
final_df=pd.concat([df_f_cat,df_standard_scaled],axis=1)

# %%
final_df
# Out:
#       MSZoning  LotShape  LandContour  LotConfig  Neighborhood  Condition1  \
# 0            3         3            3          4             5           2
# 1            3         3            3          2            24           1
# 2            3         0            3          4             5           2
# 3            3         0            3          0             6           2
# 4            3         0            3          2            15           2
# ...        ...       ...          ...        ...           ...         ...
# 1453         3         3            3          4            11           2
# 1454         1         3            3          4            21           2
# 1455         3         3            3          4             8           2
# 1458         3         3            3          4            12           2
# 1459         3         3            3          4             7           2
#
# ...

# %%
final_df.shape
# Out:
# (1238, 76)

# %%
final_df.columns
# Out:
# Index(['MSZoning', 'LotShape', 'LandContour', 'LotConfig', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'SaleType', 'SaleCondition', 'Id', 'MSSubClass', 'LotFrontage',
#        'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
# ...

# %%
from scipy.stats import chi2_contingency

# %%
chi2_results = {}
for col in []:
    contingency_table = pd.crosstab(df_cat[col], df_cat['HeartDisease'])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    chi2_results[col] = p

# %%
x=final_df.drop("SalePrice",axis=1)
y=final_df["SalePrice"]

# %%
x
# Out:
#       MSZoning  LotShape  LandContour  LotConfig  Neighborhood  Condition1  \
# 0            3         3            3          4             5           2
# 1            3         3            3          2            24           1
# 2            3         0            3          4             5           2
# 3            3         0            3          0             6           2
# 4            3         0            3          2            15           2
# ...        ...       ...          ...        ...           ...         ...
# 1453         3         3            3          4            11           2
# 1454         1         3            3          4            21           2
# 1455         3         3            3          4             8           2
# 1458         3         3            3          4            12           2
# 1459         3         3            3          4             7           2
#
# ...

# %%
y
# Out:
# 0       0.399221
# 1       0.027997
# 2       0.605456
# 3      -0.542588
# 4       0.969805
#           ...
# 1453   -1.305659
# 1454    0.076118
# 1455   -0.061372
# 1458   -0.513371
# 1459   -0.439470
# Name: SalePrice, Length: 1238, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train)
print(len(x_train))
# Out:
#       MSZoning  LotShape  LandContour  LotConfig  Neighborhood  Condition1  \
# 436          4         3            3          4            17           2
# 629          3         3            3          0            12           1
# 511          3         0            3          4            16           2
# 416          3         3            3          4            19           2
# 679          3         0            3          4            19           2
# ...        ...       ...          ...        ...           ...         ...
# 1230         3         0            3          4            19           1
# 1292         4         3            3          0            17           2
# 1336         3         0            3          4            14           1
# 1014         3         3            3          4            12           0
# 1331         3         0            3          4             5           2
#
# ...

# %%
print(y_train)
print(len(y_train))
# Out:
# 436    -0.872565
# 629    -0.150741
# 511     0.318995
# 416    -0.411972
# 679    -0.700702
#           ...
# 1230    0.144864
# 1292   -0.989431
# 1336   -0.611333
# 1014   -0.828568
# 1331   -0.645706
# Name: SalePrice, Length: 990, dtype: float64
# 990

# %%
x_test
# Out:
#       MSZoning  LotShape  LandContour  LotConfig  Neighborhood  Condition1  \
# 731          3         0            3          0            23           2
# 207          3         0            3          4            12           2
# 1023         3         3            3          4             0           2
# 1111         3         3            3          4            14           2
# 1156         3         3            3          4            12           2
# ...        ...       ...          ...        ...           ...         ...
# 1033         3         3            3          4             5           2
# 211          3         3            3          0             7           2
# 37           3         3            3          4            12           2
# 1028         3         3            3          4            12           0
# 1185         3         3            3          4             7           2
#
# ...

# %%
y_test
# Out:
# 731     0.110491
# 207    -0.528839
# 1023    0.158613
# 1111    0.351099
# 1156    0.005998
#           ...
# 1033    0.694825
# 211     0.089867
# 37     -0.363851
# 1028   -1.023804
# 1185   -1.025179
# Name: SalePrice, Length: 248, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lin_reg.score(x_train,y_train)
# Out:
# 0.9091265234316757

# %%
lin_reg.score(x_test,y_test)
# Out:
# 0.7520327617903395

# %%
y_pred=lin_reg.predict(x_test)
y_pred
# Out:
# array([ 0.43493721, -0.82652149, -0.04851566,  0.29547247, -0.21736645,
#        -1.40804762, -0.87996706, -0.8737565 , -0.50671967, -0.30098085,
#         1.59708575, -2.25132819, -1.16786231,  0.09438834, -0.67146528,
#        -0.82493526, -0.44367362, -1.02291633, -0.73412394, -1.1976785 ,
#        -0.36850003,  0.22600219, -0.85289591, -0.11912545, -1.12939861,
#         1.71216733,  1.31964713, -0.72727533, -0.78920083, -1.16557506,
#         0.821227  , -0.69760681,  0.69703922, -1.56328221,  0.14768109,
#         6.30672479, -0.56841595,  0.88513357, -0.03141461, -1.9363335 ,
#        -0.40020255, -0.27525441, -0.76263505, -0.64491225,  0.47080962,
#         0.47102547,  0.49127342, -0.8609108 , -0.27163832,  1.29984805,
#        -0.94605094, -0.836428  ,  0.10328192,  2.91278137, -0.60762818,
#         0.66022146,  1.5529123 , -0.88132789, -0.95232541,  2.50572716,
#        -1.28102031, -0.32731691, -1.62735536,  0.70811154, -0.94109747,
# ...

# %%
# # Plot actual vs predicted
# plt.scatter(y, y_pred, color='blue')
# plt.plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='dashed')  # 1:1 line
# plt.xlabel('Actual Values')
# plt.ylabel('Predicted Values')
# plt.title('Actual vs Predicted Values')
# plt.show()

# %%
for i in x:
    sns.lmplot(data=final_df, x=i,y="LotFrontage")

# %%
# Transform input data into polynomial features (degree 2)
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(x)

# Train the polynomial regression model
model = LinearRegression()
model.fit(X_poly, y)

# Predict values
y_pred = model.predict(X_poly)

# %%
y_pred
# Out:
# array([ 0.39922058,  0.02799679,  0.60545602, ..., -0.0613719 ,
#        -0.51337124, -0.43947021])

# %%
# # Visualization
# plt.scatter(x_train, y_train, color='blue', label="Actual Data")
# plt.plot(x, y_pred, color='red', linestyle="--", label="Polynomial Regression Model")
# plt.xlabel("X")
# plt.ylabel("y")
# plt.title("Polynomial Regression Example")
# plt.legend()
# plt.show()

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(x_train,y_train)
# Out:
# Ridge()

# %%
ridge.score(x_train,y_train)
# Out:
# 0.909033871859148

# %%
ridge.score(x_test,y_test)
# Out:
# 0.7531395891548254

# %%
from sklearn.tree import DecisionTreeRegressor
# Create and train the DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.metrics import accuracy_score
regressor.score(x_train,y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
regressor.score(x_test,y_test)
# Out:
# 0.6877991968993336

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
# Initialize the RandomForestRegressor
rf_reg = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model
rf_reg.fit(x_train, y_train)

# Make predictions
y_pred = rf_reg.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

# %%
rf_reg.score(x_train,y_train)
# Out:
# 0.9828415309827778

# %%
rf_reg.score(x_test,y_test)
# Out:
# 0.8107069924866479

# %%
mse
# Out:
# 0.21401757022882228

# %%
y_pred
# Out:
# array([ 8.96607725e-02, -5.08321910e-01,  1.29365219e-01,  1.38774093e-01,
#        -3.03354818e-01, -1.23067900e+00, -6.48124789e-01, -7.57080897e-01,
#        -5.74855662e-01, -1.95777738e-01,  1.42181825e+00, -1.25874737e+00,
#        -1.16165172e+00,  2.32488026e-01, -6.49356015e-01, -9.08975223e-01,
#        -3.12277938e-01, -7.69900629e-01, -4.10078083e-01, -7.10086990e-01,
#        -4.07021124e-01, -4.32297828e-02, -7.97271372e-01, -4.39057050e-01,
#        -7.21048816e-01,  1.74531063e+00,  1.31250549e+00, -6.72502506e-01,
#        -8.57755827e-01, -7.89214578e-01,  7.77109351e-01, -5.86034860e-01,
#         6.97148434e-01, -1.07101166e+00,  1.89343572e-01,  4.35753780e+00,
#        -6.40806319e-01,  1.38833207e+00, -2.58765341e-01, -1.47292466e+00,
#        -5.04503117e-01, -5.08924392e-01, -5.27848006e-01, -5.23837002e-01,
#         3.45455826e-01,  1.42396962e-01,  3.76653473e-01, -6.35050150e-01,
# ...

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Define weak learner (base estimator)
weak_learner = DecisionTreeRegressor(max_depth=1)

# Initialize AdaBoostRegressor
clf = AdaBoostRegressor(estimator=weak_learner, n_estimators=50, random_state=42)

# Train the model
clf.fit(x_train, y_train)

# Predict
y_pred = clf.predict(x_test)

# %%
clf.score(x_train,y_train)
# Out:
# 0.5134867258212068

# %%
clf.score(x_test,y_test)
# Out:
# 0.39261770193977374

# %%
y_pred=clf.predict(x_test)
y_pred
# Out:
# array([ 0.25846543, -0.017137  ,  0.25846543,  0.25846543, -0.017137  ,
#        -0.017137  , -0.01057382,  0.00924788, -0.017137  ,  0.16067903,
#         2.06208434, -0.017137  , -0.01057382,  0.25846543,  0.00924788,
#        -0.017137  , -0.017137  , -0.01057382, -0.01057382, -0.017137  ,
#        -0.01057382, -0.01057382, -0.01057382, -0.01057382, -0.017137  ,
#         2.9324729 ,  0.43528137, -0.01057382, -0.017137  , -0.01057382,
#         0.41652741, -0.017137  ,  0.37439411, -0.01057382,  0.2908752 ,
#         3.68773283, -0.01057382,  0.37439411,  0.1900645 , -0.017137  ,
#         0.17391439, -0.01057382, -0.017137  , -0.01057382,  0.29942915,
#         0.2908752 ,  0.29942915, -0.017137  , -0.01057382,  0.57748589,
#        -0.017137  , -0.01057382,  0.25846543,  3.15792705, -0.017137  ,
#         0.29942915,  0.45148187, -0.017137  , -0.01057382,  3.04119536,
#        -0.017137  , -0.01057382, -0.017137  ,  0.41652741, -0.017137  ,
# ...

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.686715718337767

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# Define model
ridge = Ridge()

# Define hyperparameter grid
param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 100]  # Regularization strength
}

# Perform GridSearchCV
grid_search = GridSearchCV(ridge, param_grid, cv=5, scoring='r2')
grid_search.fit(x_train, y_train)

# Best model
best_ridge = grid_search.best_estimator_
print("Best alpha:", grid_search.best_params_)

# Predict with best model
y_pred = best_ridge.predict(x_test)
# Out:
# Best alpha: {'alpha': 0.1}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# Define Linear Regression model
lin_reg = LinearRegression()

# Define the valid parameter grid for Linear Regression
param_grid = {
    'fit_intercept': [True, False],  # Whether to calculate the intercept
    'copy_X': [True, False],  # Whether to copy input X or overwrite it
    'positive': [True, False]  # Whether to enforce positive coefficients (added in sklearn 0.24+)
}

# Instantiate GridSearchCV
gdf = GridSearchCV(estimator=lin_reg, param_grid=param_grid, scoring='r2', cv=5)

# Fit to the training data
gdf.fit(x_train, y_train)

# Get the best parameters and best score
print("Best Parameters:", gdf.best_params_)
print("Best Score:", gdf.best_score_)
print("Best Score:", gdf.best_score_)
# Out:
# Best Parameters: {'copy_X': True, 'fit_intercept': True, 'positive': False}
# Best Score: 0.8517214150666337
# Best Score: 0.8517214150666337

# %%
import mlflow

# %%
import os
os.environ['GIT_PYTHON_REFRESH']='quiet'
#os.environ['MLFLOW_TRACKING_URI']='file:///Users/JANARDHAN/Documents/Janardhan/m1/e1'
os.environ['MLFLOW_TRACKING_URI']="file:///Users/sanja/Mlops"

# %%
mlflow.set_experiment("HousePricing-Analysis")
mlflow.set_experiment_tag('HS-tag','ex1')

# %%
import mlflow
import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

with mlflow.start_run():    
    # Model object initialization
    RandFor = RandomForestRegressor(n_estimators=5000, max_depth=6, random_state=42)
    GBM = GradientBoostingRegressor(n_estimators=3000, max_depth=6, learning_rate=0.01, min_samples_split=5, random_state=42)
    
    rf_n_estimators = 5000

    # Logging parameters
    mlflow.log_param("rf_n_estimators", rf_n_estimators)
    mlflow.log_param("rf_max_depth", 6)
    mlflow.log_param("gbm_n_estimators", 3000)
    mlflow.log_param("gbm_max_depth", 6)
    mlflow.log_param("gbm_learning_rate", 0.01)
    mlflow.log_param("gbm_minimum_samples_split", 5)
    
    # Training models
    rf = RandFor.fit(x_train, y_train)
    gbm = GBM.fit(x_train, y_train)
    
    # Training scores
    training_score_rf = rf.score(x_train, y_train)  # R^2 score
    training_score_gbm = gbm.score(x_train, y_train)  # R^2 score
    
    # Logging training score
    mlflow.log_metric("rf_training_r2", training_score_rf)
    mlflow.log_metric("gbm_training_r2", training_score_gbm)
    # Value predictions
    y_pred_rf = rf.predict(x_test)
    y_pred_gbm = gbm.predict(x_test)
    # Prediction evaluations
    testing_r2_rf = r2_score(y_test, y_pred_rf)
    testing_r2_gbm = r2_score(y_test, y_pred_gbm)
    testing_mse_rf = mean_squared_error(y_test, y_pred_rf)
    testing_mse_gbm = mean_squared_error(y_test, y_pred_gbm)
    
    # Logging evaluation scores
    mlflow.log_metric("rf_testing_r2", testing_r2_rf)
    mlflow.log_metric("gbm_testing_r2", testing_r2_gbm)
    mlflow.log_metric("rf_testing_mse", testing_mse_rf)
    mlflow.log_metric("gbm_testing_mse", testing_mse_gbm)
    
    # Logging models
    mlflow.sklearn.log_model(rf,"random-forest-regressor")
    mlflow.sklearn.log_model(gbm,"gradient-boosting-regressor")
    
    # Setting tags
    mlflow.set_tag("iteration_name","test_rf_gb_regression")
    mlflow.set_tag("feature_set_version", "loan_default")
